# %% [markdown]
# # This notebook provides a tutorial to use emulators of the linear and of the non-linear matter power spectra. We show two illustrative examples: the first involves computing both linear and non-linear spectra for a single set of parameters, while the second displays results of both spectra across a dataset of $10^5$ parameter sets.

# %%
import numpy as np
import cosmopower as cp
import matplotlib.pyplot as plt
import os
# Out:
# 2024-08-16 18:27:44.384857: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# !pip install SciencePlots
# Out:
# Requirement already satisfied: SciencePlots in /Users/osx/anaconda3/envs/staro/lib/python3.7/site-packages (2.1.1)
# Requirement already satisfied: matplotlib in /Users/osx/anaconda3/envs/staro/lib/python3.7/site-packages (from SciencePlots) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in /Users/osx/anaconda3/envs/staro/lib/python3.7/site-packages (from matplotlib->SciencePlots) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in /Users/osx/anaconda3/envs/staro/lib/python3.7/site-packages (from matplotlib->SciencePlots) (1.21.6)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/osx/anaconda3/envs/staro/lib/python3.7/site-packages (from matplotlib->SciencePlots) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/osx/anaconda3/envs/staro/lib/python3.7/site-packages (from matplotlib->SciencePlots) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/osx/anaconda3/envs/staro/lib/python3.7/site-packages (from matplotlib->SciencePlots) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/osx/anaconda3/envs/staro/lib/python3.7/site-packages (from matplotlib->SciencePlots) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /Users/osx/anaconda3/envs/staro/lib/python3.7/site-packages (from matplotlib->SciencePlots) (9.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/osx/anaconda3/envs/staro/lib/python3.7/site-packages (from matplotlib->SciencePlots) (24.0)
# Requirement already satisfied: typing-extensions in /Users/osx/anaconda3/envs/staro/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->SciencePlots) (4.7.1)
# Requirement already satisfied: six>=1.5 in /Users/osx/anaconda3/envs/staro/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->SciencePlots) (1.16.0)

# %%
plt.style.reload_library()
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
import scienceplots
plt.style.use(['science', 'notebook','ieee'])

# %% [markdown]
# ## To get started, we initialize the emulators through the $\texttt{CosmoPower}$ package.
# #### Note that both spectrum emulators are characterized by units of $[\rm h/\rm Mpc]^3$, with $k$-modes expressed in $[1/\rm Mpc]$.

# %%
lin_emu = cp.cosmopower_NN(restore=True,
                          restore_filename='../emulators/DS_linear_cp_NN_S8',
                         )

nl_emu = cp.cosmopower_NN(restore=True,
                          restore_filename='../emulators/DS_nonlinear_cp_NN_S8',
                         )
# Out:
# 2024-08-16 18:27:53.594205: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
k_modes = nl_emu.modes
k_modes_lin = lin_emu.modes

# %% [markdown]
# ## Let's explore the input parameters associated with each emulator.

# %%
lin_emu.parameters   #The parameters names are not in order for inputting.
# Out:
# ListWrapper(['w', 'S_8', 'omega_cdm', 'm_nu', 'A', 'z', 'omega_b', 'n_s', 'h'])

# %%
nl_emu.parameters    #There parameters names are not in order for inputting.
# Out:
# ListWrapper(['w', 'S_8', 'omega_cdm', 'm_nu', 'A', 'z', 'omega_b', 'n_s', 'h'])

# %% [markdown]
# ### Note that the order of the input parameters of emulators must follow that of the training stage!

# %% [markdown]
# # 1) A single parameters set
# ### We create a dictionary organized to match the order of the input parameters for the emulator.

# %%
params_single = {'omega_b': [0.02242],
                'omega_cdm': [0.11933],
                'h': [67.66/100.0],
                'n_s': [0.9665],
                'S_8': [0.8102],
                'm_nu': [0.0],
                'w': [-1.0],
                'A': [0],
                'z': [0]
                }

# %% [markdown]
# ## Easily we can now pass the orderly-arranged dictionary as input to the emulators.

# %%
Pk_lin = lin_emu.predictions_np(params_single) #This is in log10(Pk_lin)

# %%
Pk_nl = nl_emu.predictions_np(params_single) #This is in log10(Pk_nl)

# %% [markdown]
# ## For a visual representation, let's generate plots for both spectra.

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5), sharex = False, sharey= True)

ax.plot(k_modes_lin, 10**Pk_lin[0], '-', color='coral', lw=1.5, label= r'Linear')
ax.plot(k_modes, 10**Pk_nl[0], '-.', color='teal', lw=1.5, label= r'Non-linear')
ax.set_ylabel(r"$P(k, z=0) \ \mathtt{[h/Mpc]}^3$",fontsize=20)
ax.set_xlabel(r"$k \ \mathtt{[h/Mpc]}$",fontsize=20)
ax.set_xscale('log')
ax.set_yscale('log')
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
ax.legend()
plt.show()

# %% [markdown]
# # 2) A bunch of parameters set

# %% [markdown]
# ### Now, we'll proceed to emulate 100,000 spectra and record the computational timing for the calculations.
# ### Given the following dictionary:

# %%
N_params = 100000

params_set = {'omega_b': np.linspace(0.01865, 0.02625, N_params),
              'omega_cdm': np.linspace(0.1, 0.255, N_params),
              'h': np.linspace(0.64, 0.82, N_params),
              'n_s': np.linspace(0.84, 1.1, N_params),
              'S_8': np.linspace(0.6, 0.9, N_params),
              'm_nu': np.linspace(0.0, 0.2, N_params),
              'w': np.linspace(-1.3, -0.7, N_params),
              'A': np.linspace(-30.0, 30.0, N_params),
              'z': np.linspace(0.0, 5.0, N_params)
             }

# %%
# %%time
Pk_lin_array = lin_emu.predictions_np(params_set) #log10(Pk_lin)
# Out:
# CPU times: user 14.1 s, sys: 5.94 s, total: 20 s
# Wall time: 14.1 s

# %%
np.shape(Pk_lin_array)
# Out:
# (100000, 372)

# %%
# %%time
Pk_nl_array = nl_emu.predictions_np(params_set) #log10(Pk_nl)
# Out:
# CPU times: user 13.9 s, sys: 4.84 s, total: 18.8 s
# Wall time: 12.7 s

# %%
np.shape(Pk_nl_array)
# Out:
# (100000, 360)

# %% [markdown]
# ### Remarkably, each spectrum emulation has been full computed in an impressive ~14 seconds!!!

# %% [markdown]
# ## Finally, let's visualize a subset of 1000 spectra with a plot.

# %%
import matplotlib.colorbar

# %%
cmap = plt.get_cmap("winter")
  
fig, ax = plt.subplots(1, 1, figsize=(8, 5), sharex = False, sharey= True)

for param_name, ls, param in [("$A_{\\rm ds}  \quad [ \\rm b/GeV]$", "-", params_set['A'])]:
    cb_ax = matplotlib.colorbar.make_axes(ax, location='right')
    norm = matplotlib.colors.Normalize(vmin=param[0], vmax=param[-1])
    cb1 = matplotlib.colorbar.ColorbarBase(cb_ax[0], cmap=cmap, norm=norm, **cb_ax[1])

    cb1.set_label(param_name,fontsize=20)
    cb1.ax.tick_params(labelsize=15)
    for ii in range(1000):
        jj = ii*100
        _ = ax.plot(k_modes, (10**Pk_nl_array[jj]), 
                                ls=ls, c=cmap(jj/len(param)))
        
ax.set_ylabel(r"$P_{\rm NL}(k, z) \ \mathtt{[h/Mpc]}^3$",fontsize=20)
ax.set_xlabel(r"$k \ \mathtt{[h/Mpc]}$",fontsize=20)
ax.set_xscale('log')
ax.set_yscale('log')
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

plt.show()

# %% [markdown]
# #### End of the notebook.
